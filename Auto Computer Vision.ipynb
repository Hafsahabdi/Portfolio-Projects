# %%
# pip install cvlib

# %%
import cv2
import matplotlib.pyplot as plt
from cvlib.object_detection import draw_bbox
import cvlib

# %%
img=cv2.imread('cars.jpg')

# %%
img
# Out:
# array([[[224, 216, 133],
#         [224, 216, 133],
#         [220, 212, 129],
#         ...,
#         [ 11,  34,   2],
#         [ 11,  34,   2],
#         [ 11,  34,   2]],
#
#        [[229, 218, 136],
#         [227, 216, 134],
#         [225, 214, 132],
#         ...,
#         [ 11,  34,   2],
#         [ 11,  34,   2],
#         [ 11,  34,   2]],
#
#        [[239, 224, 145],
#         [236, 221, 142],
#         [235, 220, 141],
#         ...,
#         [ 11,  34,   2],
#         [ 11,  34,   2],
#         [ 11,  34,   2]],
#
#        ...,
#
#        [[194, 179, 153],
#         [203, 186, 160],
#         [203, 183, 158],
#         ...,
#         [ 59,  56,  42],
#         [ 59,  56,  42],
#         [ 59,  56,  42]],
#
#        [[193, 178, 152],
#         [198, 183, 157],
#         [197, 177, 152],
#         ...,
#         [ 59,  56,  42],
#         [ 59,  56,  42],
#         [ 59,  56,  42]],
#
#        [[192, 177, 151],
#         [195, 180, 154],
#         [191, 171, 146],
#         ...,
#         [ 59,  56,  42],
#         [ 59,  56,  42],
#         [ 59,  56,  42]]], dtype=uint8)

# %%
plt.imshow(img)

# %%
box,label,count=cvlib.detect_common_objects(img)

# %%
output=draw_bbox(img,box,label,count)

# %%
plt.figure(figsize=(10,10))
plt.imshow(output)

# %%
label.count('car')
# Out:
# 11

# %%
label
# Out:
# ['car',
#  'car',
#  'car',
#  'car',
#  'car',
#  'car',
#  'car',
#  'person',
#  'car',
#  'car',
#  'car',
#  'car']

# %%
img=cv2.imread("g8.jpg")

# %%
plt.imshow(img)

# %%
box,label,count=cvlib.detect_common_objects(img)

# %%
output=draw_bbox(img,box,label,count)

# %%
plt.figure(figsize=(10,10))
plt.imshow(output)

# %%
img=cv2.imread("kuzu.jpg")

# %%
plt.imshow(img)

# %%
box,label,count=cvlib.detect_common_objects(img)

# %%
output=draw_bbox(img,box,label,count)

# %%
plt.figure(figsize=(10,10))
plt.imshow(output)

# %%
label.count('sheep')
# Out:
# 8

# %%
import pandas as pd

# %%
pd.DataFrame(label).value_counts()
# Out:
# sheep    8
# dtype: int64
