# %% [markdown]
# # Image Processing with DNN

# %%
import tensorflow as tf

# %%
from tensorflow import keras

# %%
mnist=keras.datasets.mnist

# %%
(train_images,train_labels),(test_images,test_labels)=mnist.load_data()

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
from matplotlib import pyplot as plt
plt.imshow(train_images[0],cmap='gray')

# %%
from matplotlib import pyplot as plt
plt.imshow(train_images[59999],cmap='gray')

# %%
from matplotlib import pyplot as plt
plt.imshow(train_images[20],cmap='gray')

# %%
train_images=train_images/255.0
test_images=test_images/255.0

# %%
from matplotlib import pyplot as plt
plt.imshow(train_images[0],cmap='gray')

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Conv2D,MaxPooling2D,Flatten,InputLayer,Reshape
import tensorflow as tf

# %%
# CNN, LSTM, 
model=Sequential()
model.add(InputLayer(input_shape=(28,28))) #input layer
model.add(Reshape(target_shape=(28,28,1)))
model.add(Conv2D(filters=12,kernel_size=(3,3), activation='relu')) #CNN
model.add(MaxPooling2D(pool_size=(2,2)))   
model.add(Flatten())
model.add(Dense(10))
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              optimizer='adam',metrics='accuracy')

# %%
history=model.fit(train_images,train_labels,batch_size=128, epochs=5,verbose=1,validation_data=(test_images,test_labels))
# Out:
# Epoch 1/5
# 469/469 [==============================] - 5s 11ms/step - loss: 0.4473 - accuracy: 0.8829 - val_loss: 0.2140 - val_accuracy: 0.9393
# Epoch 2/5
# 469/469 [==============================] - 5s 11ms/step - loss: 0.1782 - accuracy: 0.9493 - val_loss: 0.1362 - val_accuracy: 0.9623
# Epoch 3/5
# 469/469 [==============================] - 5s 10ms/step - loss: 0.1277 - accuracy: 0.9644 - val_loss: 0.1040 - val_accuracy: 0.9702
# Epoch 4/5
# 469/469 [==============================] - 5s 11ms/step - loss: 0.1021 - accuracy: 0.9721 - val_loss: 0.0925 - val_accuracy: 0.9718
# Epoch 5/5
# 469/469 [==============================] - 5s 12ms/step - loss: 0.0873 - accuracy: 0.9749 - val_loss: 0.0805 - val_accuracy: 0.9769

# %%
scores=model.evaluate(test_images,test_labels)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0805 - accuracy: 0.9769

# %%
scores[1]
# Out:
# 0.9768999814987183

# %%
from keras.utils.vis_utils import plot_model

# %%
# !pip install pydot
# Out:
# Requirement already satisfied: pydot in c:\users\hafsa\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in c:\users\hafsa\anaconda3\lib\site-packages (from pydot) (3.0.9)

# %%
plot_model(model,to_file='model_plotCNN.png', show_shapes=True,show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
plt.plot(history.history['accuracy'],label='train')
plt.plot(history.history['val_accuracy'],label='test')
plt.legend()

# %% [markdown]
# # Example 2- Recognizing Clothes

# %%
fashion_mnist=tf.keras.datasets.fashion_mnist

# %%
(train_images,train_labels),(test_images,test_labels)=fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 2us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0s/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.imshow(train_images[i],cmap='gray')

# %%
train_images=train_images/255.0
test_images=test_images/255.0

# %%
model=Sequential([
    Flatten(input_shape=(28,28)),
    Dense(128,activation='relu'),
    Dense(128,activation='relu'),
    Dense(10)
])

model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              optimizer='adam',metrics='accuracy')

# %%
model.fit(train_images,train_labels,epochs=10,verbose=1)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2147 - accuracy: 0.9176
# Epoch 2/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2060 - accuracy: 0.9219
# Epoch 3/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2044 - accuracy: 0.9219
# Epoch 4/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1943 - accuracy: 0.9264
# Epoch 5/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1913 - accuracy: 0.9269
# Epoch 6/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1835 - accuracy: 0.9291
# Epoch 7/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1776 - accuracy: 0.9315
# Epoch 8/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1742 - accuracy: 0.9337
# Epoch 9/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1673 - accuracy: 0.9366
# Epoch 10/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1662 - accuracy: 0.9368

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
model=Sequential()
model.add(InputLayer(input_shape=(28,28))) #input layer
model.add(Reshape(target_shape=(28,28,1)))
model.add(Conv2D(filters=12,kernel_size=(3,3), activation='relu')) #CNN
model.add(MaxPooling2D(pool_size=(2,2)))   
model.add(Flatten())
model.add(Dense(10))
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              optimizer='adam',metrics='accuracy')

# %%
model.fit(train_images,train_labels,epochs=10,verbose=1,validation_data=(test_images,test_labels))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2680 - accuracy: 0.9050 - val_loss: 0.3058 - val_accuracy: 0.8900
# Epoch 2/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2566 - accuracy: 0.9092 - val_loss: 0.2996 - val_accuracy: 0.8908
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2476 - accuracy: 0.9126 - val_loss: 0.3066 - val_accuracy: 0.8926
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2397 - accuracy: 0.9159 - val_loss: 0.2954 - val_accuracy: 0.8949
# Epoch 5/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2330 - accuracy: 0.9175 - val_loss: 0.2871 - val_accuracy: 0.8972
# Epoch 6/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2259 - accuracy: 0.9195 - val_loss: 0.2833 - val_accuracy: 0.8987
# Epoch 7/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2212 - accuracy: 0.9217 - val_loss: 0.2881 - val_accuracy: 0.8995
# Epoch 8/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2154 - accuracy: 0.9231 - val_loss: 0.2923 - val_accuracy: 0.8989
# Epoch 9/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2099 - accuracy: 0.9249 - val_loss: 0.2886 - val_accuracy: 0.9021
# Epoch 10/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2057 - accuracy: 0.9265 - val_loss: 0.2839 - val_accuracy: 0.9004
